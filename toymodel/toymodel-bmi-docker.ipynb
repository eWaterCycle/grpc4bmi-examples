# %%
import docker
client = docker.from_env()

# %%
client.images.list(name="ewatercycle/toy*")
# Out:
# [<Image: 'ewatercycle/toymodel:latest'>]

# %%
from grpc4bmi.bmi_client_docker import BmiClientDocker

# %%
model = BmiClientDocker(image="ewatercycle/toymodel:latest", image_port=55555, 
                        work_dir="./data")

# %%
model.get_component_name()
# Out:
# 'Toymodel Lumped Edition'

# %%
model.initialize("toymodel.ini")

# %%
model.get_input_var_names()
# Out:
# ('Area', 'prec')

# %%
model.get_output_var_names()
# Out:
# ('Q',)

# %%
tstart = model.get_start_time()
tstep = model.get_time_step()
print(tstart)
# Out:
# ---------------------------------------------------------------------------
# _Rendezvous                               Traceback (most recent call last)
# <ipython-input-19-c03c5f152a89> in <module>()
# ----> 1 tstart = model.get_start_time()
#       2 tstep = model.get_time_step()
#       3 print(tstart)
#
# /home/gvdoord/Software/grpc4bmi/venv/local/lib/python2.7/site-packages/grpc4bmi-0.1.4-py2.7.egg/grpc4bmi/bmi_grpc_client.pyc in get_start_time(self)
#      89
#      90     def get_start_time(self):
# ---> 91         return self.stub.getStartTime(bmi_pb2.Empty()).time
#      92
#      93     def get_end_time(self):
#
# /home/gvdoord/Software/grpc4bmi/venv/local/lib/python2.7/site-packages/grpc/_channel.pyc in __call__(self, request, timeout, metadata, credentials)
#     512     def __call__(self, request, timeout=None, metadata=None, credentials=None):
#     513         state, call, = self._blocking(request, timeout, metadata, credentials)
# --> 514         return _end_unary_response_blocking(state, call, False, None)
#     515
#     516     def with_call(self, request, timeout=None, metadata=None, credentials=None):
#
# /home/gvdoord/Software/grpc4bmi/venv/local/lib/python2.7/site-packages/grpc/_channel.pyc in _end_unary_response_blocking(state, call, with_call, deadline)
#     446             return state.response
#     447     else:
# --> 448         raise _Rendezvous(state, None, None, deadline)
#     449
#     450
#
# _Rendezvous: <_Rendezvous of RPC that terminated with:
# 	status = StatusCode.UNKNOWN
# 	details = "Exception calling application: '2001-01-01' has type str, but expected one of: int, long, float"
# 	debug_error_string = "{"created":"@1539899610.363450587","description":"Error received from peer","file":"src/core/lib/surface/call.cc","file_line":1095,"grpc_message":"Exception calling application: '2001-01-01' has type str, but expected one of: int, long, float","grpc_status":2}"
# >

# %%
# %time model.update_until(tstart + 100 * tstep)
print(model.get_current_time())
# Out:
# CPU times: user 240 µs, sys: 4.61 ms, total: 4.85 ms
# Wall time: 18 s
# 800150400.0
